# %%
import urllib.request 
print(urllib.request.urlopen("http://stackoverflow.com/documentation/"))
# Prints: <http.client.HTTPResponse at 0x7f37a97e3b00>
response = urllib.request.urlopen("http://stackoverflow.com/documentation/")
print(response.code)
# Prints: 200
print(response.read()[:50])
# Prints: b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n\r\n<title>Documentation - Stack Overflow</title>
# Out:
# <http.client.HTTPResponse object at 0x000001B998BC2400>
# 200
# b'<!DOCTYPE html>\r\n\r\n\r\n    <html class="html__respon'

# %%
import urllib
query_parms = {'username':'stackoverflow', 'password':'me.me'}
encoded_parms = urllib.parse.urlencode(query_parms).encode('utf-8')
response = urllib.request.urlopen("https://stackoverflow.com/users/login", encoded_parms) 
response.code
# Output: 200
response.read()[:100]
# Output: b'<!DOCTYPE html>\r\n<html>....etc'
# Out:
# b'<!DOCTYPE html>\r\n\r\n\r\n    <html class="html__responsive html__unpinned-leftnav">\r\n\r\n    <head>\r\n\r\n   '

# %%
from selenium import webdriver
browser = webdriver.Firefox() # launch Firefox browser browser.get('http://stackoverflow.com/questions?sort=votes') # load url
#title = browser.find_element_by_css_selector('h1').text # page title (first h1 element)
questions = browser.find_elements_by_css_selector('.question-summary') # question list
for question in questions: # iterate over questions
    question_title = question.find_element_by_css_selector('.summary h3 a').text 
    question_excerpt = question.find_element_by_css_selector('.summary .excerpt').text 
    question_vote = question.find_element_by_css_selector('.stats .vote .votes .vote-count-post').text
    print("%s\n%s\n%s votes\n-----------\n" % (question_title, question_excerpt, question_vote))

# %%
! python -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (19.1.1)

# %%
# ModuleNotFoundError: No module named 'selenium'
! pip install selenium
# Out:
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from selenium) (1.22)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# Out:
# Requirement already satisfied: requests in c:\users\gayoungkim\appdata\local\programs\python\python36\lib\site-packages (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\gayoungkim\appdata\local\programs\python\python36\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gayoungkim\appdata\local\programs\python\python36\lib\site-packages (from requests) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gayoungkim\appdata\local\programs\python\python36\lib\site-packages (from requests) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\gayoungkim\appdata\local\programs\python\python36\lib\site-packages (from requests) (2.8)

# %%
import requests
from bs4 import BeautifulSoup

# 1) reqeusts 라이브러리를 활용한 HTML 페이지 요청 
# 1-1) res 객체에 HTML 데이터가 저장되고, res.content로 데이터를 추출할 수 있음
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# print(res.content)
# 2) HTML 페이지 파싱 BeautifulSoup(HTML데이터, 파싱방법)
# 2-1) BeautifulSoup 파싱방법
soup = BeautifulSoup(res.content, 'html.parser')

# 3) 필요한 데이터 검색
title = soup.find('title')

# 4) 필요한 데이터 추출
print(title.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토 | Daum 뉴스

# %%
import re
import urllib.request

url = "http://goo.gl/U7mSQl"             # 접속할 페이지
html = urllib.request.urlopen(url)       # 페이지 열기
html_contents = str(html.read())         # 페이지의 내용을 문자열로 가져옴
id_results = re.findall(r"([A-Za-z0-9]+\*\*\*)", html_contents)
# findall 전체 찾기, 정규 표현식 패턴 대로 데이터 찾기

for result in id_results:                 # 찾은 정보를 화면에 출력
    print (result)
# Out:
# codo***
# outb7***
# dubba4***
# multicuspi***
# crownm***
# triformo***
# spania***
# magazin***
# presby***
# trophody***
# nontr***
# enranck***
# canc***
# uncanker***
# wrymo***
# non***
# luminat***
# oblig***
# anna***
# hyperth***
# toplabl***
# dolce0***
# rudals2***
# jjw980***
# elvlz***
# skmid***
# qkep***
# kisslov***
# maskman***
# sungt***

# %% [markdown]
# ## 액셀 다루기

# %% [markdown]
# ### 1. 설치하기

# %%
#! pip install xlrd

# %% [markdown]
# ### 2. 액셀 시트 읽어오기

# %%
import xlrd 
book=xlrd.open_workbook('sample.xlsx')

print book.nsheets  # 시트 갯수 체크
print book.sheet_names() # 시트 명 체크
# Out:
#   File "<ipython-input-4-61de912408eb>", line 4
#     print book.nsheets  # 시트 갯수 체크
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(book.nsheets  # 시트 갯수 체크)?

# %% [markdown]
# # pip install bs4

# %% [markdown]
# # BeautifulSoup 라이브러리

# %%
import requests
from bs4 import BeautifulSoup

# 1) reqeusts 라이브러리를 활용한 HTML 페이지 요청 
# 1-1) res 객체에 HTML 데이터가 저장되고, res.content로 데이터를 추출할 수 있음
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# print(res.content)
# 2) HTML 페이지 파싱 BeautifulSoup(HTML데이터, 파싱방법)
# 2-1) BeautifulSoup 파싱방법
soup = BeautifulSoup(res.content, 'html.parser')

# 3) 필요한 데이터 검색
title = soup.find('title')

# 4) 필요한 데이터 추출
print(title.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토 | Daum 뉴스

# %%
from bs4 import BeautifulSoup

html = "<html> \
            <body> \
                <h1 id='title'>[1]크롤링이란?</h1> \
                <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p> \
                <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
            </body> \
        </html>"

soup = BeautifulSoup(html, "html.parser")

# 태그로 검색 방법
title_data = soup.find('h1')

print(title_data)
print(title_data.string)
print(title_data.get_text())
# Out:
# <h1 id="title">[1]크롤링이란?</h1>
# [1]크롤링이란?
# [1]크롤링이란?

# %% [markdown]
# ## CSV 다루기

# %%
import pandas as pd
d = {'a': (1, 101), 'b': (2, 202), 'c': (3, 303)}
df = pd.DataFrame.from_dict(d, orient="index")
df.to_csv("data.csv")

# %%
df = pd.read_csv("data.csv")
d = df.to_dict()

# %%
d
# Out:
# {'Unnamed: 0': {0: 'a', 1: 'b', 2: 'c'},
#  '0': {0: 1, 1: 2, 2: 3},
#  '1': {0: 101, 1: 202, 2: 303}}

# %%
import pandas as pd
df = pd.read_csv("data.csv")
d = df.to_dict()
d
# Out:
# {'0': {0: 1, 1: 2, 2: 3},
#  '1': {0: 101, 1: 202, 2: 303},
#  'Unnamed: 0': {0: 'a', 1: 'b', 2: 'c'}}

# %%
from urllib.parse import urlparse

result = urlparse('https://username:password@www.python.org:8080/doc/;parameter?q=example#hoge')

print('geturl    ',result.geturl())
print("scheme    ",result.scheme)
print('netloc    ',result.netloc)
print("username  ",result.username)
print("password  ",result.password)
print("hostname  ",result.hostname)
print("port      ",result.port)
print("path      ",result.path)
print("parameter ",result.params)
print("query     ",result.query)
print("fragment  ",result.fragment)
print(result.index("https"))
print(result.count("https"))
# Out:
# geturl     https://username:password@www.python.org:8080/doc/;parameter?q=example#hoge
# scheme     https
# netloc     username:password@www.python.org:8080
# username   username
# password   password
# hostname   www.python.org
# port       8080
# path       /doc/
# parameter  parameter
# query      q=example
# fragment   hoge
# 0
# 1

# %% [markdown]
# # python url parsing하기
# #url 구조

# %%
from urllib.parse import urlparse

parts = urlparse('https://velog.io/tags/?sort=name')

print(parts.scheme) # 'https'
print(parts.netloc) # 'velog.io:80'
print(parts.path) # '/tags/'
print(parts.params) # ''
print(parts.query) # 'sort=name'
print(parts.fragment) # ''
print(parts) # ParseResult(scheme='https', netloc='velog.io:80', path='/tags/', params='', query='sort=name', fragment='')
# Out:
# https
# velog.io
# /tags/
#
# sort=name
#
# ParseResult(scheme='https', netloc='velog.io', path='/tags/', params='', query='sort=name', fragment='')

# %%
from urllib.parse import urlparse, parse_qs, parse_qsl

urls = 'https://www.python.org/?field1=value1&field2=value2&field3=value3'
result = urlparse(urls)
print(result.query)
a = parse_qs(result.query)
print(a)
b = parse_qsl(result.query)
print(b)
# Out:
# field1=value1&field2=value2&field3=value3
# {'field1': ['value1'], 'field2': ['value2'], 'field3': ['value3']}
# [('field1', 'value1'), ('field2', 'value2'), ('field3', 'value3')]

# %%
import csv

csvfile = open('data-text.csv', 'r')
reader = csv.reader(csvfile)

for row in reader:
    print(row)
# Out:
# ['Indicator', 'PUBLISH STATES', 'Year', 'WHO region', 'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Andorra', 'Both sexes', '77', '77.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Andorra', 'Both sexes', '80', '80.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Andorra', 'Female', '28', '28.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Andorra', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'United Arab Emirates', 'Female', '78', '78.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Americas', 'High-income', 'Antigua and Barbuda', 'Male', '72', '72.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'High-income', 'Antigua and Barbuda', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Americas', 'High-income', 'Antigua and Barbuda', 'Both sexes', '22', '22.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Australia', 'Male', '81', '81.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Australia', 'Both sexes', '80', '80.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Australia', 'Both sexes', '83', '83.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Austria', 'Female', '83', '83.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Austria', 'Female', '25', '25.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Belgium', 'Female', '83', '83.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Bahrain', 'Male', '73', '73.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Bahrain', 'Female', '74', '74.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Bahrain', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Americas', 'High-income', 'Bahamas', 'Male', '72', '72.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Americas', 'High-income', 'Bahamas', 'Both sexes', '21', '21.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Americas', 'High-income', 'Barbados', 'Male', '71', '71.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Americas', 'High-income', 'Barbados', 'Female', '25', '25.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Americas', 'High-income', 'Barbados', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Western Pacific', 'High-income', 'Brunei Darussalam', 'Female', '20', '20.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Brunei Darussalam', 'Female', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Brunei Darussalam', 'Female', '21', '21.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Americas', 'High-income', 'Canada', 'Female', '82', '82.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Americas', 'High-income', 'Canada', 'Male', '21', '21.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'High-income', 'Canada', 'Female', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Switzerland', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Switzerland', 'Both sexes', '83', '83.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Switzerland', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Cook Islands', 'Both sexes', '76', '76.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Cook Islands', 'Female', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Cook Islands', 'Both sexes', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Cyprus', 'Female', '79', '79.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Cyprus', 'Both sexes', '77', '77.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Cyprus', 'Female', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Cyprus', 'Female', '26', '26.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Czech Republic', 'Male', '75', '75.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Czech Republic', 'Female', '75', '75.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Germany', 'Female', '79', '79.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Germany', 'Male', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Germany', 'Male', '20', '20.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Denmark', 'Both sexes', '80', '80.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Denmark', 'Male', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Denmark', 'Male', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Denmark', 'Both sexes', '21', '21.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Denmark', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Spain', 'Both sexes', '82', '82.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Spain', 'Female', '25', '25.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Spain', 'Both sexes', '22', '22.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Estonia', 'Female', '75', '75.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Estonia', 'Female', '81', '81.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Estonia', 'Male', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Estonia', 'Female', '21', '21.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Estonia', 'Female', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Finland', 'Female', '79', '79.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Finland', 'Male', '22', '22.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'France', 'Male', '75', '75.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'France', 'Male', '20', '20.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'United Kingdom of Great Britain and Northern Ireland', 'Female', '83', '83.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'United Kingdom of Great Britain and Northern Ireland', 'Both sexes', '81', '81.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'United Kingdom of Great Britain and Northern Ireland', 'Male', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'High-income', 'Equatorial Guinea', 'Female', '52', '52.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'High-income', 'Equatorial Guinea', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'High-income', 'Equatorial Guinea', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Greece', 'Male', '78', '78.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Greece', 'Female', '83', '83.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Croatia', 'Both sexes', '78', '78.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Croatia', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Croatia', 'Both sexes', '19', '19.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Hungary', 'Male', '68', '68.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Hungary', 'Both sexes', '72', '72.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Hungary', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Hungary', 'Female', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Hungary', 'Both sexes', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Ireland', 'Both sexes', '77', '77.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Ireland', 'Both sexes', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Ireland', 'Both sexes', '20', '20.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Iceland', 'Female', '84', '84.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Iceland', 'Female', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Israel', 'Male', '75', '75.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Israel', 'Male', '21', '21.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Israel', 'Both sexes', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Italy', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Italy', 'Male', '77', '77.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Italy', 'Male', '21', '21.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Italy', 'Both sexes', '25', '25.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Japan', 'Female', '29', '29.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Western Pacific', 'High-income', 'Japan', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Japan', 'Both sexes', '25', '25.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'High-income', 'Republic of Korea', 'Female', '76', '76.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'High-income', 'Republic of Korea', 'Both sexes', '72', '72.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Republic of Korea', 'Female', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Kuwait', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Kuwait', 'Female', '76', '76.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Kuwait', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Luxembourg', 'Male', '75', '75.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Luxembourg', 'Both sexes', '82', '82.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Luxembourg', 'Male', '20', '20.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Luxembourg', 'Both sexes', '25', '25.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Monaco', 'Both sexes', '80', '80.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Monaco', 'Both sexes', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Malta', 'Female', '78', '78.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Malta', 'Female', '80', '80.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Malta', 'Both sexes', '76', '76.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'Malta', 'Female', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Norway', 'Male', '76', '76.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Norway', 'Female', '80', '80.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Nauru', 'Male', '73', '73.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'High-income', 'Nauru', 'Both sexes', '73', '73.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'Nauru', 'Both sexes', '77', '77.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Nauru', 'Female', '27', '27.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'New Zealand', 'Both sexes', '79', '79.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'High-income', 'New Zealand', 'Female', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'Oman', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Oman', 'Female', '70', '70.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'Oman', 'Female', '78', '78.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Oman', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Oman', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'Oman', 'Female', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Portugal', 'Male', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Portugal', 'Both sexes', '24', '24.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Eastern Mediterranean', 'High-income', 'Qatar', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Qatar', 'Male', '77', '77.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Qatar', 'Both sexes', '77', '77.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'Qatar', 'Both sexes', '22', '22.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Saudi Arabia', 'Both sexes', '73', '73.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'San Marino', 'Male', '78', '78.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'San Marino', 'Male', '82', '82.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'San Marino', 'Female', '85', '85.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'San Marino', 'Male', '20', '20.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'High-income', 'San Marino', 'Male', '22', '22.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'San Marino', 'Female', '25', '25.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Slovakia', 'Male', '66', '66.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Slovakia', 'Both sexes', '73', '73.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Slovakia', 'Both sexes', '76', '76.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Slovenia', 'Male', '70', '70.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Slovenia', 'Female', '83', '83.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Slovenia', 'Both sexes', '74', '74.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'High-income', 'Slovenia', 'Both sexes', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'High-income', 'Slovenia', 'Both sexes', '23', '23.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'High-income', 'Sweden', 'Both sexes', '78', '78.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Americas', 'High-income', 'Trinidad and Tobago', 'Male', '67', '67.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Americas', 'High-income', 'Trinidad and Tobago', 'Female', '71', '71.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'High-income', 'Trinidad and Tobago', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Afghanistan', 'Both sexes', '55', '55.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Afghanistan', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Eastern Mediterranean', 'Low-income', 'Afghanistan', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Burundi', 'Female', '51', '51.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Burundi', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Benin', 'Male', '51', '51.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Benin', 'Male', '53', '53.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Benin', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Benin', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Burkina Faso', 'Male', '48', '48.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Burkina Faso', 'Male', '49', '49.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Burkina Faso', 'Both sexes', '58', '58.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Burkina Faso', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Burkina Faso', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Bangladesh', 'Both sexes', '65', '65.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'South-East Asia', 'Low-income', 'Bangladesh', 'Both sexes', '70', '70.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Bangladesh', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'South-East Asia', 'Low-income', 'Bangladesh', 'Female', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Bangladesh', 'Both sexes', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Central African Republic', 'Female', '50', '50.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Central African Republic', 'Female', '52', '52.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Central African Republic', 'Both sexes', '48', '48.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Central African Republic', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Central African Republic', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Democratic Republic of the Congo', 'Female', '50', '50.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Democratic Republic of the Congo', 'Male', '14', '14.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Democratic Republic of the Congo', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Democratic Republic of the Congo', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Comoros', 'Male', '57', '57.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Comoros', 'Male', '60', '60.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Comoros', 'Both sexes', '59', '59.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Comoros', 'Male', '14', '14.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Comoros', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Comoros', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Eritrea', 'Female', '66', '66.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Eritrea', 'Both sexes', '48', '48.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Eritrea', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Ethiopia', 'Female', '65', '65.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Ethiopia', 'Both sexes', '51', '51.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Ethiopia', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Ethiopia', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Ghana', 'Female', '59', '59.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Ghana', 'Female', '64', '64.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Ghana', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Guinea', 'Male', '57', '57.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Guinea', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Guinea', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Gambia', 'Both sexes', '61', '61.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Gambia', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Gambia', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Gambia', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Guinea-Bissau', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Americas', 'Low-income', 'Haiti', 'Female', '57', '57.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Americas', 'Low-income', 'Haiti', 'Female', '64', '64.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'Low-income', 'Haiti', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Americas', 'Low-income', 'Haiti', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Kenya', 'Both sexes', '61', '61.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Kenya', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Kenya', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'Low-income', 'Kyrgyzstan', 'Male', '62', '62.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'Low-income', 'Kyrgyzstan', 'Male', '62', '62.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'Low-income', 'Kyrgyzstan', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'Low-income', 'Kyrgyzstan', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'Low-income', 'Kyrgyzstan', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'Low-income', 'Cambodia', 'Both sexes', '54', '54.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'Low-income', 'Cambodia', 'Both sexes', '61', '61.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'Low-income', 'Cambodia', 'Both sexes', '72', '72.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Western Pacific', 'Low-income', 'Cambodia', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Western Pacific', 'Low-income', 'Cambodia', 'Both sexes', '20', '20.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'Low-income', "Lao People's Democratic Republic", 'Female', '67', '67.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Western Pacific', 'Low-income', "Lao People's Democratic Republic", 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'Low-income', "Lao People's Democratic Republic", 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Liberia', 'Male', '50', '50.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Liberia', 'Female', '52', '52.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Madagascar', 'Male', '50', '50.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Madagascar', 'Male', '57', '57.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Madagascar', 'Male', '62', '62.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Madagascar', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mali', 'Female', '57', '57.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Mali', 'Both sexes', '46', '46.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mali', 'Both sexes', '14', '14.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'South-East Asia', 'Low-income', 'Myanmar', 'Female', '61', '61.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'South-East Asia', 'Low-income', 'Myanmar', 'Female', '68', '68.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Myanmar', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'South-East Asia', 'Low-income', 'Myanmar', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'South-East Asia', 'Low-income', 'Myanmar', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mozambique', 'Male', '52', '52.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Mozambique', 'Female', '45', '45.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mozambique', 'Female', '49', '49.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mozambique', 'Female', '54', '54.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mozambique', 'Male', '14', '14.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mozambique', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Mauritania', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mauritania', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mauritania', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Malawi', 'Both sexes', '59', '59.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Malawi', 'Male', '14', '14.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Malawi', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Malawi', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Niger', 'Female', '59', '59.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Niger', 'Both sexes', '43', '43.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Niger', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'Low-income', 'Niue', 'Female', '75', '75.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'Low-income', 'Niue', 'Female', '76', '76.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'Low-income', 'Niue', 'Female', '21', '21.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Nepal', 'Male', '61', '61.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'South-East Asia', 'Low-income', 'Nepal', 'Male', '14', '14.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'South-East Asia', 'Low-income', 'Nepal', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'South-East Asia', 'Low-income', "Democratic People's Republic of Korea", 'Male', '60', '60.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'South-East Asia', 'Low-income', "Democratic People's Republic of Korea", 'Both sexes', '70', '70.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'South-East Asia', 'Low-income', "Democratic People's Republic of Korea", 'Male', '12', '12.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Rwanda', 'Female', '66', '66.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Rwanda', 'Both sexes', '48', '48.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Rwanda', 'Both sexes', '65', '65.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Rwanda', 'Female', '19', '19.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Senegal', 'Female', '59', '59.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Senegal', 'Both sexes', '57', '57.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Senegal', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Senegal', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Sierra Leone', 'Male', '11', '11.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Somalia', 'Male', '49', '49.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Somalia', 'Both sexes', '50', '50.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Somalia', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'South Sudan', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Eastern Mediterranean', 'Low-income', 'South Sudan', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Chad', 'Female', '52', '52.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Chad', 'Female', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Togo', 'Female', '56', '56.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'Low-income', 'Tajikistan', 'Both sexes', '68', '68.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'Low-income', 'Tajikistan', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'Low-income', 'Tajikistan', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'Low-income', 'Tajikistan', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'United Republic of Tanzania', 'Both sexes', '61', '61.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'United Republic of Tanzania', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Uganda', 'Female', '46', '46.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Low-income', 'Uganda', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'Low-income', 'Uzbekistan', 'Female', '69', '69.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'Low-income', 'Uzbekistan', 'Female', '18', '18.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Western Pacific', 'Low-income', 'Viet Nam', 'Male', '66', '66.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'Low-income', 'Viet Nam', 'Male', '69', '69.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'Low-income', 'Viet Nam', 'Male', '71', '71.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Western Pacific', 'Low-income', 'Viet Nam', 'Both sexes', '22', '22.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Eastern Mediterranean', 'Low-income', 'Yemen', 'Both sexes', '58', '58.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'Low-income', 'Yemen', 'Both sexes', '64', '64.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Low-income', 'Zambia', 'Both sexes', '43', '43.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Zambia', 'Both sexes', '41', '41.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Zambia', 'Both sexes', '57', '57.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Low-income', 'Zambia', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Zimbabwe', 'Female', '60', '60.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Low-income', 'Zimbabwe', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', 'Angola', 'Male', '50', '50.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Angola', 'Both sexes', '46', '46.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Angola', 'Both sexes', '15', '15.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'Lower-middle-income', 'Albania', 'Male', '67', '67.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Europe', 'Lower-middle-income', 'Albania', 'Both sexes', '74', '74.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'Lower-middle-income', 'Albania', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'Lower-middle-income', 'Albania', 'Both sexes', '19', '19.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Europe', 'Lower-middle-income', 'Armenia', 'Female', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Europe', 'Lower-middle-income', 'Armenia', 'Both sexes', '67', '67.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Europe', 'Lower-middle-income', 'Armenia', 'Female', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Europe', 'Lower-middle-income', 'Armenia', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Europe', 'Lower-middle-income', 'Azerbaijan', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Americas', 'Lower-middle-income', 'Belize', 'Female', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Americas', 'Lower-middle-income', 'Belize', 'Both sexes', '75', '75.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'Lower-middle-income', 'Belize', 'Male', '18', '18.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'Belize', 'Male', '17', '17.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Male', '61', '61.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Both sexes', '58', '58.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Both sexes', '68', '68.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Male', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Female', '20', '20.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Americas', 'Lower-middle-income', 'Bolivia (Plurinational State of)', 'Both sexes', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'South-East Asia', 'Lower-middle-income', 'Bhutan', 'Female', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'South-East Asia', 'Lower-middle-income', 'Bhutan', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'South-East Asia', 'Lower-middle-income', 'Bhutan', 'Female', '19', '19.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'South-East Asia', 'Lower-middle-income', 'Bhutan', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'China', 'Male', '74', '74.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Western Pacific', 'Lower-middle-income', 'China', 'Female', '73', '73.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Western Pacific', 'Lower-middle-income', 'China', 'Female', '19', '19.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '1990', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Male', '50', '50.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Male', '52', '52.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', "C척te d'Ivoire", 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Cameroon', 'Male', '15', '15.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', 'Cameroon', 'Both sexes', '16', '16.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Congo', 'Both sexes', '52', '52.00000', '', '', '']
# ['Life expectancy at birth (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', 'Congo', 'Both sexes', '59', '59.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Congo', 'Female', '17', '17.00000', '', '', '']
# ['Life expectancy at age 60 (years)', 'Published', '1990', 'Africa', 'Lower-middle-income', 'Congo', 'Both sexes', '16', '16.00000', '', '', '']
# ...
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Liberia', 'Male', '43', '43.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Upper-middle-income', 'Libya', 'Male', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Upper-middle-income', 'Libya', 'Female', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Upper-middle-income', 'Saint Lucia', 'Both sexes', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'South-East Asia', 'Lower-middle-income', 'Sri Lanka', 'Female', '68', '68.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Lower-middle-income', 'Lesotho', 'Female', '43', '43.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'Lithuania', 'Male', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Luxembourg', 'Female', '73', '73.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Luxembourg', 'Both sexes', '72', '72.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'Upper-middle-income', 'Latvia', 'Both sexes', '65', '65.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'Monaco', 'Female', '73', '73.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Madagascar', 'Male', '49', '49.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Lower-middle-income', 'Maldives', 'Female', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Lower-middle-income', 'Maldives', 'Both sexes', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Upper-middle-income', 'Mexico', 'Both sexes', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Mexico', 'Both sexes', '67', '67.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'The former Yugoslav republic of Macedonia', 'Male', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'The former Yugoslav republic of Macedonia', 'Female', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mali', 'Female', '40', '40.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'Montenegro', 'Male', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'Montenegro', 'Both sexes', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'Mongolia', 'Both sexes', '60', '60.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Mozambique', 'Female', '46', '46.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Mauritania', 'Female', '51', '51.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Upper-middle-income', 'Mauritius', 'Both sexes', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Malawi', 'Female', '51', '51.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Upper-middle-income', 'Namibia', 'Female', '49', '49.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Upper-middle-income', 'Namibia', 'Male', '55', '55.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Niger', 'Male', '50', '50.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Niger', 'Both sexes', '50', '50.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', 'Nigeria', 'Female', '47', '47.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'Nicaragua', 'Male', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'Nicaragua', 'Female', '65', '65.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Western Pacific', 'Low-income', 'Niue', 'Both sexes', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Low-income', 'Niue', 'Female', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Netherlands', 'Male', '70', '70.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Netherlands', 'Both sexes', '71', '71.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Low-income', 'Nepal', 'Male', '53', '53.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Nauru', 'Male', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'Nauru', 'Both sexes', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'High-income', 'New Zealand', 'Female', '73', '73.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Oman', 'Male', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Oman', 'Female', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Lower-middle-income', 'Pakistan', 'Male', '53', '53.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'Lower-middle-income', 'Pakistan', 'Male', '56', '56.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Panama', 'Both sexes', '67', '67.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Western Pacific', 'Lower-middle-income', 'Philippines', 'Male', '57', '57.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Upper-middle-income', 'Palau', 'Both sexes', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'Poland', 'Male', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Upper-middle-income', 'Poland', 'Female', '68', '68.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Low-income', "Democratic People's Republic of Korea", 'Male', '55', '55.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'South-East Asia', 'Low-income', "Democratic People's Republic of Korea", 'Male', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Portugal', 'Both sexes', '71', '71.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'Paraguay', 'Male', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'Upper-middle-income', 'Romania', 'Male', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'Upper-middle-income', 'Romania', 'Female', '69', '69.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'High-income', 'Saudi Arabia', 'Female', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'High-income', 'Saudi Arabia', 'Male', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Lower-middle-income', 'Sudan', 'Both sexes', '49', '49.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'Lower-middle-income', 'Sudan', 'Both sexes', '53', '53.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Senegal', 'Both sexes', '55', '55.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'Solomon Islands', 'Female', '60', '60.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Sierra Leone', 'Female', '39', '39.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Lower-middle-income', 'El Salvador', 'Female', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'San Marino', 'Female', '74', '74.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'High-income', 'San Marino', 'Both sexes', '72', '72.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'San Marino', 'Male', '72', '72.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Low-income', 'Somalia', 'Both sexes', '43', '43.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'Low-income', 'Somalia', 'Female', '46', '46.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'Upper-middle-income', 'Serbia', 'Female', '67', '67.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Suriname', 'Both sexes', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'High-income', 'Sweden', 'Both sexes', '72', '72.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Lower-middle-income', 'Swaziland', 'Female', '47', '47.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Upper-middle-income', 'Seychelles', 'Male', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Lower-middle-income', 'Syrian Arab Republic', 'Female', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Chad', 'Female', '44', '44.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Lower-middle-income', 'Thailand', 'Male', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'South-East Asia', 'Lower-middle-income', 'Thailand', 'Female', '65', '65.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Low-income', 'Tajikistan', 'Both sexes', '56', '56.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Europe', 'Low-income', 'Tajikistan', 'Female', '60', '60.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'Tonga', 'Female', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'High-income', 'Trinidad and Tobago', 'Female', '64', '64.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'High-income', 'Trinidad and Tobago', 'Both sexes', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Eastern Mediterranean', 'Lower-middle-income', 'Tunisia', 'Male', '63', '63.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Upper-middle-income', 'Tuvalu', 'Male', '57', '57.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Uganda', 'Female', '40', '40.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Europe', 'Lower-middle-income', 'Ukraine', 'Both sexes', '60', '60.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Uruguay', 'Male', '65', '65.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Uruguay', 'Female', '70', '70.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Uruguay', 'Both sexes', '68', '68.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Americas', 'Upper-middle-income', 'Saint Vincent and the Grenadines', 'Both sexes', '61', '61.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Americas', 'Upper-middle-income', 'Venezuela (Bolivarian Republic of)', 'Both sexes', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Western Pacific', 'Lower-middle-income', 'Vanuatu', 'Male', '59', '59.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'Samoa', 'Male', '62', '62.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Western Pacific', 'Lower-middle-income', 'Samoa', 'Female', '66', '66.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Eastern Mediterranean', 'Low-income', 'Yemen', 'Both sexes', '54', '54.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Upper-middle-income', 'South Africa', 'Male', '49', '49.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2000', 'Africa', 'Low-income', 'Zambia', 'Both sexes', '36', '36.00000', '', '', '']
# ['Healthy life expectancy (HALE) at birth (years)', 'Published', '2012', 'Africa', 'Low-income', 'Zimbabwe', 'Female', '51', '51.00000', '', '', '']

# %%
import csv

csvfile = open('data-text.csv', 'r')
reader = csv.DictReader(csvfile)

for row in reader:
    print(row)
# Out:
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Andorra'), ('Sex', 'Both sexes'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Andorra'), ('Sex', 'Both sexes'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Andorra'), ('Sex', 'Female'), ('Display Value', '28'), ('Numeric', '28.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Andorra'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'United Arab Emirates'), ('Sex', 'Female'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Antigua and Barbuda'), ('Sex', 'Male'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Antigua and Barbuda'), ('Sex', 'Male'), ('Display Value', '17'), ('Numeric', '17.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Antigua and Barbuda'), ('Sex', 'Both sexes'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Australia'), ('Sex', 'Male'), ('Display Value', '81'), ('Numeric', '81.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Australia'), ('Sex', 'Both sexes'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Australia'), ('Sex', 'Both sexes'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Austria'), ('Sex', 'Female'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Austria'), ('Sex', 'Female'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Belgium'), ('Sex', 'Female'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Bahrain'), ('Sex', 'Male'), ('Display Value', '73'), ('Numeric', '73.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Bahrain'), ('Sex', 'Female'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Bahrain'), ('Sex', 'Male'), ('Display Value', '17'), ('Numeric', '17.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Bahamas'), ('Sex', 'Male'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Bahamas'), ('Sex', 'Both sexes'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Barbados'), ('Sex', 'Male'), ('Display Value', '71'), ('Numeric', '71.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Barbados'), ('Sex', 'Female'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Barbados'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Brunei Darussalam'), ('Sex', 'Female'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Brunei Darussalam'), ('Sex', 'Female'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Brunei Darussalam'), ('Sex', 'Female'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Canada'), ('Sex', 'Female'), ('Display Value', '82'), ('Numeric', '82.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Canada'), ('Sex', 'Male'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Canada'), ('Sex', 'Female'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Switzerland'), ('Sex', 'Male'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Switzerland'), ('Sex', 'Both sexes'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Switzerland'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Cook Islands'), ('Sex', 'Both sexes'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Cook Islands'), ('Sex', 'Female'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Cook Islands'), ('Sex', 'Both sexes'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Cyprus'), ('Sex', 'Female'), ('Display Value', '79'), ('Numeric', '79.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Cyprus'), ('Sex', 'Both sexes'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Cyprus'), ('Sex', 'Female'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Cyprus'), ('Sex', 'Female'), ('Display Value', '26'), ('Numeric', '26.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Czech Republic'), ('Sex', 'Male'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Czech Republic'), ('Sex', 'Female'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Germany'), ('Sex', 'Female'), ('Display Value', '79'), ('Numeric', '79.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Germany'), ('Sex', 'Male'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Germany'), ('Sex', 'Male'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Denmark'), ('Sex', 'Both sexes'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Denmark'), ('Sex', 'Male'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Denmark'), ('Sex', 'Male'), ('Display Value', '19'), ('Numeric', '19.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Denmark'), ('Sex', 'Both sexes'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Denmark'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Spain'), ('Sex', 'Both sexes'), ('Display Value', '82'), ('Numeric', '82.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Spain'), ('Sex', 'Female'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Spain'), ('Sex', 'Both sexes'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Estonia'), ('Sex', 'Female'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Estonia'), ('Sex', 'Female'), ('Display Value', '81'), ('Numeric', '81.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Estonia'), ('Sex', 'Male'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Estonia'), ('Sex', 'Female'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Estonia'), ('Sex', 'Female'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Finland'), ('Sex', 'Female'), ('Display Value', '79'), ('Numeric', '79.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Finland'), ('Sex', 'Male'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'France'), ('Sex', 'Male'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'France'), ('Sex', 'Male'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'United Kingdom of Great Britain and Northern Ireland'), ('Sex', 'Female'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'United Kingdom of Great Britain and Northern Ireland'), ('Sex', 'Both sexes'), ('Display Value', '81'), ('Numeric', '81.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'United Kingdom of Great Britain and Northern Ireland'), ('Sex', 'Male'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Africa'), ('World Bank income group', 'High-income'), ('Country', 'Equatorial Guinea'), ('Sex', 'Female'), ('Display Value', '52'), ('Numeric', '52.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Africa'), ('World Bank income group', 'High-income'), ('Country', 'Equatorial Guinea'), ('Sex', 'Female'), ('Display Value', '15'), ('Numeric', '15.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'High-income'), ('Country', 'Equatorial Guinea'), ('Sex', 'Female'), ('Display Value', '17'), ('Numeric', '17.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Greece'), ('Sex', 'Male'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Greece'), ('Sex', 'Female'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Croatia'), ('Sex', 'Both sexes'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Croatia'), ('Sex', 'Male'), ('Display Value', '16'), ('Numeric', '16.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Croatia'), ('Sex', 'Both sexes'), ('Display Value', '19'), ('Numeric', '19.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Hungary'), ('Sex', 'Male'), ('Display Value', '68'), ('Numeric', '68.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Hungary'), ('Sex', 'Both sexes'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Hungary'), ('Sex', 'Male'), ('Display Value', '15'), ('Numeric', '15.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Hungary'), ('Sex', 'Female'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Hungary'), ('Sex', 'Both sexes'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Ireland'), ('Sex', 'Both sexes'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Ireland'), ('Sex', 'Both sexes'), ('Display Value', '19'), ('Numeric', '19.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Ireland'), ('Sex', 'Both sexes'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Iceland'), ('Sex', 'Female'), ('Display Value', '84'), ('Numeric', '84.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Iceland'), ('Sex', 'Female'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Israel'), ('Sex', 'Male'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Israel'), ('Sex', 'Male'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Israel'), ('Sex', 'Both sexes'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Italy'), ('Sex', 'Male'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Italy'), ('Sex', 'Male'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Italy'), ('Sex', 'Male'), ('Display Value', '21'), ('Numeric', '21.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Italy'), ('Sex', 'Both sexes'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Japan'), ('Sex', 'Female'), ('Display Value', '29'), ('Numeric', '29.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Japan'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Japan'), ('Sex', 'Both sexes'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Republic of Korea'), ('Sex', 'Female'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Republic of Korea'), ('Sex', 'Both sexes'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Republic of Korea'), ('Sex', 'Female'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Kuwait'), ('Sex', 'Male'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Kuwait'), ('Sex', 'Female'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Kuwait'), ('Sex', 'Female'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Luxembourg'), ('Sex', 'Male'), ('Display Value', '75'), ('Numeric', '75.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Luxembourg'), ('Sex', 'Both sexes'), ('Display Value', '82'), ('Numeric', '82.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Luxembourg'), ('Sex', 'Male'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Luxembourg'), ('Sex', 'Both sexes'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Monaco'), ('Sex', 'Both sexes'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Monaco'), ('Sex', 'Both sexes'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Malta'), ('Sex', 'Female'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Malta'), ('Sex', 'Female'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Malta'), ('Sex', 'Both sexes'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Malta'), ('Sex', 'Female'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Norway'), ('Sex', 'Male'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Norway'), ('Sex', 'Female'), ('Display Value', '80'), ('Numeric', '80.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Nauru'), ('Sex', 'Male'), ('Display Value', '73'), ('Numeric', '73.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Nauru'), ('Sex', 'Both sexes'), ('Display Value', '73'), ('Numeric', '73.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Nauru'), ('Sex', 'Both sexes'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'Nauru'), ('Sex', 'Female'), ('Display Value', '27'), ('Numeric', '27.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'New Zealand'), ('Sex', 'Both sexes'), ('Display Value', '79'), ('Numeric', '79.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'High-income'), ('Country', 'New Zealand'), ('Sex', 'Female'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Male'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Female'), ('Display Value', '70'), ('Numeric', '70.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Female'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Male'), ('Display Value', '17'), ('Numeric', '17.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Female'), ('Display Value', '18'), ('Numeric', '18.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Oman'), ('Sex', 'Female'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Portugal'), ('Sex', 'Male'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Portugal'), ('Sex', 'Both sexes'), ('Display Value', '24'), ('Numeric', '24.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Qatar'), ('Sex', 'Male'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Qatar'), ('Sex', 'Male'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Qatar'), ('Sex', 'Both sexes'), ('Display Value', '77'), ('Numeric', '77.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Qatar'), ('Sex', 'Both sexes'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Saudi Arabia'), ('Sex', 'Both sexes'), ('Display Value', '73'), ('Numeric', '73.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Male'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Male'), ('Display Value', '82'), ('Numeric', '82.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Female'), ('Display Value', '85'), ('Numeric', '85.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Male'), ('Display Value', '20'), ('Numeric', '20.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Male'), ('Display Value', '22'), ('Numeric', '22.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Female'), ('Display Value', '25'), ('Numeric', '25.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovakia'), ('Sex', 'Male'), ('Display Value', '66'), ('Numeric', '66.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovakia'), ('Sex', 'Both sexes'), ('Display Value', '73'), ('Numeric', '73.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovakia'), ('Sex', 'Both sexes'), ('Display Value', '76'), ('Numeric', '76.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovenia'), ('Sex', 'Male'), ('Display Value', '70'), ('Numeric', '70.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovenia'), ('Sex', 'Female'), ('Display Value', '83'), ('Numeric', '83.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovenia'), ('Sex', 'Both sexes'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovenia'), ('Sex', 'Both sexes'), ('Display Value', '19'), ('Numeric', '19.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at age 60 (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Slovenia'), ('Sex', 'Both sexes'), ('Display Value', '23'), ('Numeric', '23.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Sweden'), ('Sex', 'Both sexes'), ('Display Value', '78'), ('Numeric', '78.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Trinidad and Tobago'), ('Sex', 'Male'), ('Display Value', '67'), ('Numeric', '67.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Life expectancy at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '1990'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Trinidad and Tobago'), ('Sex', 'Female'), ('Display Value', '71'), ('Numeric', '71.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# ...
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Romania'), ('Sex', 'Male'), ('Display Value', '63'), ('Numeric', '63.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Romania'), ('Sex', 'Female'), ('Display Value', '69'), ('Numeric', '69.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Saudi Arabia'), ('Sex', 'Female'), ('Display Value', '63'), ('Numeric', '63.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'High-income'), ('Country', 'Saudi Arabia'), ('Sex', 'Male'), ('Display Value', '64'), ('Numeric', '64.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Sudan'), ('Sex', 'Both sexes'), ('Display Value', '49'), ('Numeric', '49.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Sudan'), ('Sex', 'Both sexes'), ('Display Value', '53'), ('Numeric', '53.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Senegal'), ('Sex', 'Both sexes'), ('Display Value', '55'), ('Numeric', '55.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Solomon Islands'), ('Sex', 'Female'), ('Display Value', '60'), ('Numeric', '60.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Sierra Leone'), ('Sex', 'Female'), ('Display Value', '39'), ('Numeric', '39.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'El Salvador'), ('Sex', 'Female'), ('Display Value', '64'), ('Numeric', '64.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Female'), ('Display Value', '74'), ('Numeric', '74.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Both sexes'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'San Marino'), ('Sex', 'Male'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Low-income'), ('Country', 'Somalia'), ('Sex', 'Both sexes'), ('Display Value', '43'), ('Numeric', '43.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Low-income'), ('Country', 'Somalia'), ('Sex', 'Female'), ('Display Value', '46'), ('Numeric', '46.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Serbia'), ('Sex', 'Female'), ('Display Value', '67'), ('Numeric', '67.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Suriname'), ('Sex', 'Both sexes'), ('Display Value', '66'), ('Numeric', '66.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'High-income'), ('Country', 'Sweden'), ('Sex', 'Both sexes'), ('Display Value', '72'), ('Numeric', '72.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Swaziland'), ('Sex', 'Female'), ('Display Value', '47'), ('Numeric', '47.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Africa'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Seychelles'), ('Sex', 'Male'), ('Display Value', '61'), ('Numeric', '61.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Syrian Arab Republic'), ('Sex', 'Female'), ('Display Value', '64'), ('Numeric', '64.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Chad'), ('Sex', 'Female'), ('Display Value', '44'), ('Numeric', '44.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'South-East Asia'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Thailand'), ('Sex', 'Male'), ('Display Value', '59'), ('Numeric', '59.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'South-East Asia'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Thailand'), ('Sex', 'Female'), ('Display Value', '65'), ('Numeric', '65.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'Low-income'), ('Country', 'Tajikistan'), ('Sex', 'Both sexes'), ('Display Value', '56'), ('Numeric', '56.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Europe'), ('World Bank income group', 'Low-income'), ('Country', 'Tajikistan'), ('Sex', 'Female'), ('Display Value', '60'), ('Numeric', '60.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Tonga'), ('Sex', 'Female'), ('Display Value', '61'), ('Numeric', '61.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Trinidad and Tobago'), ('Sex', 'Female'), ('Display Value', '64'), ('Numeric', '64.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'High-income'), ('Country', 'Trinidad and Tobago'), ('Sex', 'Both sexes'), ('Display Value', '61'), ('Numeric', '61.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Tunisia'), ('Sex', 'Male'), ('Display Value', '63'), ('Numeric', '63.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Tuvalu'), ('Sex', 'Male'), ('Display Value', '57'), ('Numeric', '57.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Uganda'), ('Sex', 'Female'), ('Display Value', '40'), ('Numeric', '40.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Europe'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Ukraine'), ('Sex', 'Both sexes'), ('Display Value', '60'), ('Numeric', '60.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Uruguay'), ('Sex', 'Male'), ('Display Value', '65'), ('Numeric', '65.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Uruguay'), ('Sex', 'Female'), ('Display Value', '70'), ('Numeric', '70.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Uruguay'), ('Sex', 'Both sexes'), ('Display Value', '68'), ('Numeric', '68.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Saint Vincent and the Grenadines'), ('Sex', 'Both sexes'), ('Display Value', '61'), ('Numeric', '61.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Americas'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'Venezuela (Bolivarian Republic of)'), ('Sex', 'Both sexes'), ('Display Value', '66'), ('Numeric', '66.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Vanuatu'), ('Sex', 'Male'), ('Display Value', '59'), ('Numeric', '59.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Samoa'), ('Sex', 'Male'), ('Display Value', '62'), ('Numeric', '62.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Western Pacific'), ('World Bank income group', 'Lower-middle-income'), ('Country', 'Samoa'), ('Sex', 'Female'), ('Display Value', '66'), ('Numeric', '66.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Eastern Mediterranean'), ('World Bank income group', 'Low-income'), ('Country', 'Yemen'), ('Sex', 'Both sexes'), ('Display Value', '54'), ('Numeric', '54.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Africa'), ('World Bank income group', 'Upper-middle-income'), ('Country', 'South Africa'), ('Sex', 'Male'), ('Display Value', '49'), ('Numeric', '49.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2000'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Zambia'), ('Sex', 'Both sexes'), ('Display Value', '36'), ('Numeric', '36.00000'), ('Low', ''), ('High', ''), ('Comments', '')])
# OrderedDict([('Indicator', 'Healthy life expectancy (HALE) at birth (years)'), ('PUBLISH STATES', 'Published'), ('Year', '2012'), ('WHO region', 'Africa'), ('World Bank income group', 'Low-income'), ('Country', 'Zimbabwe'), ('Sex', 'Female'), ('Display Value', '51'), ('Numeric', '51.00000'), ('Low', ''), ('High', ''), ('Comments', '')])

# %%
import json
d = {'foo': 'bar',
'alice': 1,
'wonderland': [1, 2, 3]
}
with open('data.json', 'w') as f:
    json.dump(d, f)

# %%
import json
with open('data.json', 'r') as f:
    d = json.load(f)

# %%
print(d)
# Out:
# {'foo': 'bar', 'alice': 1, 'wonderland': [1, 2, 3]}

# %%
from __future__ import print_function
import lxml.html
import requests
def main():
    r = requests.get("https://httpbin.org")
    html_source = r.text
    root_element = lxml.html.fromstring(html_source)
# Note root_element.xpath() gives a *list* of results.
# XPath specifies a path to the element we want.
    page_title = root_element.xpath('/html/head/title/text()')[0]
    print(page_title)
if __name__ == '__main__':
    main()
# Out:
# httpbin.org

# %%
from bs4 import BeautifulSoup
import requests
# Use the requests module to obtain a page
res = requests.get('https://www.codechef.com/problems/easy')
# Create a BeautifulSoup object
page = BeautifulSoup(res.text, 'lxml') # the text field contains the source of the page
# Now use a CSS selector in order to get the table containing the list of problems
datatable_tags = page.select('table.dataTable') # The problems are in the <table> tag,
# with class "dataTable"
# We extract the first tag from the list, since that's what we desire
datatable = datatable_tags[0]
# Now since we want problem names, they are contained in <b> tags, which are
# directly nested under <a> tags
prob_tags = datatable.select('a > b')
prob_names = [tag.getText().strip() for tag in prob_tags]
print(prob_names)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-6f028a051c4c> in <module>()
#       9 # with class "dataTable"
#      10 # We extract the first tag from the list, since that's what we desire
# ---> 11 datatable = datatable_tags[0]
#      12 # Now since we want problem names, they are contained in <b> tags, which are
#      13 # directly nested under <a> tags
#
# IndexError: list index out of range

# %% [markdown]
# # 엑셀다루기

# %%
import xml.etree.ElementTree as elemTree
 
 
xmlStr = '''
            <users>
                    <user grade="gold">
                        <name>Kim Cheol Soo</name>
                        <age>25</age>
                        <birthday>19940215</birthday>
                    </user>
                    <user grade="diamond">
                        <name>Kim Yoo Mee</name>
                        <age>21</age>
                        <birthday>19980417</birthday>
                    </user>
            </users>
        '''
 
tree = elemTree.fromstring(xmlStr)
user = tree.find('./user') #첫번째 user를 검색한 후 마침
 
 
print(user.tag) #tag name -> user
print(user.attrib) #{'grade' : 'gold'}
print(user.get('grade')) #attr value -> gold
 
 
userName = user.find('name') #<name></name> tag
print(userName.text) #Kim Cheol Soo
# Out:
# user
# {'grade': 'gold'}
# gold
# Kim Cheol Soo

# %%
import xlrd

wb=xlrd.open_workbook("kbo_rank.xlsx")
ws=wb.sheet_by_index(0)

print(wb.sheet_names())
# Out:
# ['Sheet1']

# %%
print(ws.cell_value(1,1))
# Out:
# 두산

# %%
print(ws.col_values(1)[1])
print(ws.col_values(1)[2])

print(ws.row_values(0)[1])
print(ws.row_values(0)[2])
# Out:
# 두산
# SK
# 팀명
# 경기

# %%
nrow = ws.nrows
ncol = ws.ncols

print (nrow)  # 행(가로줄 수)
print (ncol)  # 열(세로줄 수)
# Out:
# 11
# 12

# %%
from lxml import html
import requests
page = requests.get('http://econpy.pythonanywhere.com/ex/001.html')
tree = html.fromstring(page.content)
#This will create a list of buyers:
buyers = tree.xpath('//div[@title="buyer-name"]/text()')
#This will create a list of prices
prices = tree.xpath('//span[@class="item-price"]/text()')

print('Buyers:' , buyers)
print('Prices:' , prices)
# Out:
# Buyers: ['Carson Busses', 'Earl E. Byrd', 'Patty Cakes', 'Derri Anne Connecticut', 'Moe Dess', 'Leda Doggslife', 'Dan Druff', 'Al Fresco', 'Ido Hoe', 'Howie Kisses', 'Len Lease', 'Phil Meup', 'Ira Pent', 'Ben D. Rules', 'Ave Sectomy', 'Gary Shattire', 'Bobbi Soks', 'Sheila Takya', 'Rose Tattoo', 'Moe Tell']
# Prices: ['$29.95', '$8.37', '$15.26', '$19.25', '$19.25', '$13.99', '$31.57', '$8.49', '$14.47', '$15.86', '$11.11', '$15.98', '$16.27', '$7.50', '$50.85', '$14.26', '$5.68', '$15.00', '$114.07', '$10.09']

# %%
import xlwt

wb = xlwt.Workbook(encoding = "utf-8")
ws = wb.add_sheet('sheet1')

ws.write(0, 0, "순위")
ws.write(0, 1, "이름")
ws.write(1, 0, "1")
ws.write(1, 1, "Ronaldo")
ws.write(2, 0, "2")
ws.write(2, 1, "Rashford")
ws.write(3, 0, "3")
ws.write(3, 1, "lsco")

wb.save("player.xls")

# %%
import json
d = {
    "foo" : "bar",
    "alice" : 1,
    "wonderland" : [1, 2, 3]
}

with open('data.json', 'w') as f: json.dump(d, f)

    
with open('data.json', 'r') as f: d = json.load(f)
    
print(d)
# Out:
# {'alice': 1, 'foo': 'bar', 'wonderland': [1, 2, 3]}

# %%
from bs4 import BeautifulSoup
data = """
<ul>
<li class = "item">item1</li>
<li class = "item">item2</li>
<li class = "item">item3</li>
</ul>
"""

soup = BeautifulSoup(data, "html.parser")
for item in soup.select("li.item"):
    print(item.get_text())
# Out:
# item1
# item2
# item3
